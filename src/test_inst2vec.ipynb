# %%
from observation.inst2vec import Inst2vecEncoder
import multiprocessing as mp
from tqdm import tqdm
from datasets import load_dataset, load_from_disk
from itertools import islice
import subprocess
import tempfile
import os
from typing import Union
from pathlib import Path
import numpy as np
from transformers import AutoTokenizer

# %%
data_path = '/home/xucong24/ComPile'
llvm_path = '/usr/lib/llvm-14/bin/llvm-dis'

# %%
with open('/home/xucong24/Compiler/datasets/poj104/ir_test/1/24.ll', 'r') as f:
    llvm = f.read()

# %%
tokenizer = AutoTokenizer.from_pretrained("/home/xucong24/Compiler/checkpoints/ModernBERT-base")

# %%
len(tokenizer(llvm).input_ids)
# Out:
# 3725
